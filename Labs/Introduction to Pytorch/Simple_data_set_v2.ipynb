# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# <h1>Simple Dataset</h1>

# %% [markdown]
# <h2>Objective</h2><ul><li> How to create a dataset in pytorch.</li><li> How to perform transformations on the dataset.</li></ul>

# %% [markdown]
# <h2>Table of Contents</h2>

# %% [markdown]
# <p>In this lab, you will construct a basic dataset by using PyTorch and learn how to apply basic transformations to it.</p>
# <ul>
#     <li><a href="#Simple-dataset">Simple dataset</a></li>
#     <li><a href="#Transforms">Transforms</a></li>
#     <li><a href="#Compose">Compose</a></li>
# </ul>
# <p>Estimated Time Needed: <strong>30 min</strong></p>
# <hr>

# %% [markdown]
# <h2>Preparation</h2>

# %% [markdown]
# The following are the libraries we are going to use for this lab. The <code>torch.manual_seed()</code> is for forcing the random function to give the same number every time we try to recompile it.

# %%
# %%time
# %pip install torch==2.8.0+cpu torchvision==0.23.0+cpu torchaudio==2.8.0+cpu  --index-url https://download.pytorch.org/whl/cpu
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cpu
# Collecting torch==2.8.0+cpu
#   Downloading torch-2.8.0%2Bcpu-cp312-cp312-win_amd64.whl.metadata (29 kB)
# Collecting torchvision==0.23.0+cpu
#   Downloading torchvision-0.23.0%2Bcpu-cp312-cp312-win_amd64.whl.metadata (6.3 kB)
# Collecting torchaudio==2.8.0+cpu
#   Downloading torchaudio-2.8.0%2Bcpu-cp312-cp312-win_amd64.whl.metadata (7.4 kB)
# Requirement already satisfied: filelock in c:\Users\adars\AppData\Local\Programs\Python\Python312\Lib\site-packages (from torch==2.8.0+cpu) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\Users\adars\AppData\Local\Programs\Python\Python312\Lib\site-packages (from torch==2.8.0+cpu) (4.15.0)
# Collecting sympy>=1.13.3 (from torch==2.8.0+cpu)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: networkx in c:\Users\adars\AppData\Local\Programs\Python\Python312\Lib\site-packages (from torch==2.8.0+cpu) (3.2.1)
# Requirement already satisfied: jinja2 in c:\Users\adars\AppData\Local\Programs\Python\Python312\Lib\site-packages (from torch==2.8.0+cpu) (3.1.3)
# Requirement already satisfied: fsspec in c:\Users\adars\AppData\Local\Programs\Python\Python312\Lib\site-packages (from torch==2.8.0+cpu) (2024.3.0)
# Requirement already satisfied: setuptools in c:\Users\adars\AppData\Local\Programs\Python\Python312\Lib\site-packages (from torch==2.8.0+cpu) (69.2.0)
# Requirement already satisfied: numpy in c:\Users\adars\AppData\Local\Programs\Python\Python312\Lib\site-packages (from torchvision==0.23.0+cpu) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\Users\adars\AppData\Local\Programs\Python\Python312\Lib\site-packages (from torchvision==0.23.0+cpu) (12.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\Users\adars\AppData\Local\Programs\Python\Python312\Lib\site-packages (from sympy>=1.13.3->torch==2.8.0+cpu) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\Users\adars\AppData\Local\Programs\Python\Python312\Lib\site-packages (from jinja2->torch==2.8.0+cpu) (2.1.5)
# Downloading torch-2.8.0%2Bcpu-cp312-cp312-win_amd64.whl (619.4 MB)
#    ---------------------------------------- 0.0/619.4 MB ? eta -:--:--
#    ---------------------------------------- 1.6/619.4 MB 11.9 MB/s eta 0:00:52
#    ---------------------------------------- 5.5/619.4 MB 16.0 MB/s eta 0:00:39
#     --------------------------------------- 10.2/619.4 MB 18.7 MB/s eta 0:00:33
#     --------------------------------------- 13.4/619.4 MB 18.2 MB/s eta 0:00:34
#    - -------------------------------------- 17.8/619.4 MB 19.0 MB/s eta 0:00:32
#    - -------------------------------------- 21.0/619.4 MB 18.4 MB/s eta 0:00:33
#    - -------------------------------------- 25.4/619.4 MB 18.7 MB/s eta 0:00:32
#    - -------------------------------------- 29.6/619.4 MB 19.0 MB/s eta 0:00:32
#    -- ------------------------------------- 34.1/619.4 MB 19.3 MB/s eta 0:00:31
#    -- ------------------------------------- 37.5/619.4 MB 18.9 MB/s eta 0:00:31
#    -- ------------------------------------- 42.2/619.4 MB 19.4 MB/s eta 0:00:30
#    -- ------------------------------------- 46.4/619.4 MB 19.5 MB/s eta 0:00:30
#    --- ------------------------------------ 50.9/619.4 MB 19.5 MB/s eta 0:00:30
#    --- ------------------------------------ 54.8/619.4 MB 19.5 MB/s eta 0:00:29
#    --- ------------------------------------ 56.4/619.4 MB 18.7 MB/s eta 0:00:31
#    --- ------------------------------------ 59.5/619.4 MB 18.6 MB/s eta 0:00:31
#    ---- ----------------------------------- 64.0/619.4 MB 18.6 MB/s eta 0:00:30
#    ---- ----------------------------------- 66.6/619.4 MB 18.3 MB/s eta 0:00:31
#    ---- ----------------------------------- 70.8/619.4 MB 18.4 MB/s eta 0:00:30
#    ---- ----------------------------------- 75.5/619.4 MB 18.6 MB/s eta 0:00:30
#    ----- ---------------------------------- 78.4/619.4 MB 18.4 MB/s eta 0:00:30
#    ----- ---------------------------------- 82.3/619.4 MB 18.4 MB/s eta 0:00:30
#    ------------------------------------ -- 577.0/619.4 MB 15.9 MB/s eta 0:00:03
#    ------------------------------------ -- 580.1/619.4 MB 15.7 MB/s eta 0:00:03
#    ------------------------------------ -- 584.1/619.4 MB 15.8 MB/s eta 0:00:03
#    ------------------------------------- - 587.7/619.4 MB 16.4 MB/s eta 0:00:02
#    ------------------------------------- - 591.4/619.4 MB 16.4 MB/s eta 0:00:02
#    ------------------------------------- - 595.3/619.4 MB 16.4 MB/s eta 0:00:02
#    ------------------------------------- - 599.0/619.4 MB 16.4 MB/s eta 0:00:02
#    ------------------------------------- - 602.9/619.4 MB 16.4 MB/s eta 0:00:02
#    --------------------------------------  607.4/619.4 MB 16.4 MB/s eta 0:00:01
#    --------------------------------------  611.8/619.4 MB 16.4 MB/s eta 0:00:01
#    --------------------------------------  616.6/619.4 MB 16.4 MB/s eta 0:00:01
#    --------------------------------------  619.2/619.4 MB 16.7 MB/s eta 0:00:01
#    --------------------------------------  619.2/619.4 MB 16.7 MB/s eta 0:00:01
#    --------------------------------------  619.2/619.4 MB 16.7 MB/s eta 0:00:01
#    --------------------------------------  619.2/619.4 MB 16.7 MB/s eta 0:00:01
#    --------------------------------------  619.2/619.4 MB 16.7 MB/s eta 0:00:01
#    ---------------------------------------- 619.4/619.4 MB 15.7 MB/s  0:00:39
# Downloading torchvision-0.23.0%2Bcpu-cp312-cp312-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 1.6/1.6 MB 8.6 MB/s  0:00:00
# Downloading torchaudio-2.8.0%2Bcpu-cp312-cp312-win_amd64.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 2.5/2.5 MB 17.9 MB/s  0:00:00
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ------------------------ --------------- 3.9/6.3 MB 19.5 MB/s eta 0:00:01
#    ---------------------------------------- 6.3/6.3 MB 18.4 MB/s  0:00:00
# Installing collected packages: sympy, torch, torchvision, torchaudio
#
#   Attempting uninstall: sympy
#
#     Found existing installation: sympy 1.12
#
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#     Uninstalling sympy-1.12:
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#       Successfully uninstalled sympy-1.12
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#    ---------------------------------------- 0/4 [sympy]
#   Attempting uninstall: torch
#    ---------------------------------------- 0/4 [sympy]
#     Found existing installation: torch 2.2.1
#    ---------------------------------------- 0/4 [sympy]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#     Uninstalling torch-2.2.1:
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#       Successfully uninstalled torch-2.2.1
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    ---------- ----------------------------- 1/4 [torch]
#    -------------------- ------------------- 2/4 [torchvision]
#    -------------------- ------------------- 2/4 [torchvision]
#    -------------------- ------------------- 2/4 [torchvision]
#    -------------------- ------------------- 2/4 [torchvision]
#    -------------------- ------------------- 2/4 [torchvision]
#    -------------------- ------------------- 2/4 [torchvision]
#    ------------------------------ --------- 3/4 [torchaudio]
#    ------------------------------ --------- 3/4 [torchaudio]
#    ------------------------------ --------- 3/4 [torchaudio]
#    ------------------------------ --------- 3/4 [torchaudio]
#    ---------------------------------------- 4/4 [torchaudio]
#
# Successfully installed sympy-1.14.0 torch-2.8.0+cpu torchaudio-2.8.0+cpu torchvision-0.23.0+cpu
# Note: you may need to restart the kernel to use updated packages.
# CPU times: total: 594 ms
# Wall time: 1min 54s

# %%
# These are the libraries will be used for this lab.

import torch
from torch.utils.data import Dataset
torch.manual_seed(1)

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="Simple-dataset">Simple dataset</h2>

# %% [markdown]
# Let us try to create our own dataset class.

# %%
# Define class for dataset

class toy_set(Dataset):
    
    # Constructor with defult values 
    def __init__(self, length = 100, transform = None):
        self.len = length
        self.x = 2 * torch.ones(length, 2)
        self.y = torch.ones(length, 1)
        self.transform = transform
     
    # Getter
    def __getitem__(self, index):
        sample = self.x[index], self.y[index]
        if self.transform:
            sample = self.transform(sample)     
        return sample
    
    # Get Length
    def __len__(self):
        return self.len

# %% [markdown]
# Now, let us create our <code>toy_set</code> object, and find out the value on index 1 and the length of the inital dataset

# %%
# Create Dataset Object. Find out the value on index 1. Find out the length of Dataset Object.

our_dataset = toy_set()
print("Our toy_set object: ", our_dataset)
print("Value on index 0 of our toy_set object: ", our_dataset[0])
print("Our toy_set length: ", len(our_dataset))
# Out:
# Our toy_set object:  <__main__.toy_set object at 0x0000025DDECF11F0>
# Value on index 0 of our toy_set object:  (tensor([2., 2.]), tensor([1.]))
# Our toy_set length:  100

# %% [markdown]
# As a result, we can apply the same indexing convention as a <code>list</code>,
# and apply the fuction <code>len</code> on the <code>toy_set</code> object. We are able to customize the indexing and length method by <code>def &#95;&#95;getitem&#95;&#95;(self, index)</code> and <code>def &#95;&#95;len&#95;&#95;(self)</code>.

# %% [markdown]
# Now, let us print out the first 3 elements and assign them to x and y:

# %%
# Use loop to print out all elements in dataset

for i in range(len(our_dataset)):
    x, y=our_dataset[i]
    print("index: ", i, '; x:', x, '; y:', y)
# Out:
# index:  0 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  1 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  2 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  3 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  4 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  5 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  6 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  7 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  8 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  9 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  10 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  11 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  12 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  13 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  14 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  15 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  16 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  17 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  18 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  19 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  20 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  21 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  22 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  23 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  24 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  25 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  26 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  27 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  28 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  29 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  30 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  31 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  32 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  33 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  34 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  35 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  36 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  37 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  38 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  39 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  40 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  41 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  42 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  43 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  44 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  45 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  46 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  47 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  48 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  49 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  50 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  51 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  52 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  53 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  54 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  55 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  56 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  57 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  58 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  59 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  60 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  61 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  62 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  63 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  64 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  65 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  66 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  67 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  68 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  69 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  70 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  71 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  72 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  73 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  74 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  75 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  76 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  77 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  78 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  79 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  80 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  81 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  82 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  83 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  84 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  85 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  86 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  87 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  88 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  89 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  90 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  91 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  92 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  93 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  94 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  95 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  96 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  97 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  98 ; x: tensor([2., 2.]) ; y: tensor([1.])
# index:  99 ; x: tensor([2., 2.]) ; y: tensor([1.])

# %% [markdown]
# The dataset object is an Iterable; as a result, we  apply the loop directly on the dataset object

# %%
for x,y in our_dataset:
    print(' x:', x, 'y:', y)
# Out:
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])
#  x: tensor([2., 2.]) y: tensor([1.])

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h3>Practice</h3>

# %% [markdown]
# Try to create an <code>toy_set</code> object with length <b>50</b>. Print out the length of your object.

# %%
# Practice: Create a new object with length 50, and print the length of object out.

class toy_set(Dataset):
    
    def __init__(self, length=50, transform=None):
        self.x = 2 * torch.ones(length, 2)
        self.y = torch.ones(length,1)
        
        self.len = length
        
        self.transform = transform
    
    def __len__(self):
        
        return self.len
        
        
    def __getitem__(self, index):
        
        sample = self.x[index],self.y[index]
        
        if self.transform:
            sample = self.transform(sample)
        return sample

new_dataset = toy_set()
print("Length of new dataset: ", len(new_dataset))
# Out:
# Length of new dataset:  50

# %% [markdown]
# Double-click <b>here</b> for the solution.
# <!--
# my_dataset = toy_set(length = 50)
# print("My toy_set length: ", len(my_dataset))
# -->

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="Transforms">Transforms</h2>

# %% [markdown]
# You can also create a class for transforming the data. In this case, we will try to add 1 to x and multiply y by 2:

# %%
# Create tranform class add_mult

class add_mult(object):
    
    # Constructor
    def __init__(self, addx = 1, muly = 2):
        self.addx = addx
        self.muly = muly
    
    # Executor
    def __call__(self, sample):
        x = sample[0]
        y = sample[1]
        x = x + self.addx
        y = y * self.muly
        sample = x, y
        return sample

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# Now, create a transform object:.

# %%
# Create an add_mult transform object, and an toy_set object

a_m = add_mult()
data_set = toy_set()

# %% [markdown]
# Assign the outputs of the original dataset to <code>x</code> and <code>y</code>. Then, apply the transform <code>add_mult</code> to the dataset and output the values as <code>x_</code> and <code>y_</code>, respectively:

# %%
# Use loop to print out first 10 elements in dataset

for i in range(10):
    x, y = data_set[i]
    print('Index: ', i, 'Original x: ', x, 'Original y: ', y)
    x_, y_ = a_m(data_set[i])
    print('Index: ', i, 'Transformed x_:', x_, 'Transformed y_:', y_)
# Out:
# Index:  0 Original x:  tensor([2., 2.]) Original y:  tensor([1.])
# Index:  0 Transformed x_: tensor([3., 3.]) Transformed y_: tensor([2.])
# Index:  1 Original x:  tensor([2., 2.]) Original y:  tensor([1.])
# Index:  1 Transformed x_: tensor([3., 3.]) Transformed y_: tensor([2.])
# Index:  2 Original x:  tensor([2., 2.]) Original y:  tensor([1.])
# Index:  2 Transformed x_: tensor([3., 3.]) Transformed y_: tensor([2.])
# Index:  3 Original x:  tensor([2., 2.]) Original y:  tensor([1.])
# Index:  3 Transformed x_: tensor([3., 3.]) Transformed y_: tensor([2.])
# Index:  4 Original x:  tensor([2., 2.]) Original y:  tensor([1.])
# Index:  4 Transformed x_: tensor([3., 3.]) Transformed y_: tensor([2.])
# Index:  5 Original x:  tensor([2., 2.]) Original y:  tensor([1.])
# Index:  5 Transformed x_: tensor([3., 3.]) Transformed y_: tensor([2.])
# Index:  6 Original x:  tensor([2., 2.]) Original y:  tensor([1.])
# Index:  6 Transformed x_: tensor([3., 3.]) Transformed y_: tensor([2.])
# Index:  7 Original x:  tensor([2., 2.]) Original y:  tensor([1.])
# Index:  7 Transformed x_: tensor([3., 3.]) Transformed y_: tensor([2.])
# Index:  8 Original x:  tensor([2., 2.]) Original y:  tensor([1.])
# Index:  8 Transformed x_: tensor([3., 3.]) Transformed y_: tensor([2.])
# Index:  9 Original x:  tensor([2., 2.]) Original y:  tensor([1.])
# Index:  9 Transformed x_: tensor([3., 3.]) Transformed y_: tensor([2.])

# %% [markdown]
# As the result, <code>x</code> has been added by 1 and y has been multiplied by 2, as <i>[2, 2] + 1 = [3, 3]</i> and <i>[1] x 2 = [2]</i>

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# We can apply the transform object every time we create a new <code>toy_set object</code>? Remember, we have the constructor in toy_set class with the parameter <code>transform = None</code>.
# When we create a new object using the constructor, we can assign the transform object to the parameter transform, as the following code demonstrates.

# %%
# Create a new data_set object with add_mult object as transform

cust_data_set = toy_set(transform = a_m)

# %% [markdown]
# This applied <code>a_m</code> object (a transform method) to every element in <code>cust_data_set</code> as initialized. Let us print out the first 10 elements in <code>cust_data_set</code> in order to see whether the <code>a_m</code> applied on <code>cust_data_set</code>

# %%
# Use loop to print out first 10 elements in dataset

for i in range(10):
    x, y = data_set[i]
    print('Index: ', i, 'Original x: ', x, 'Original y: ', y)
    x_, y_ = cust_data_set[i]
    print('Index: ', i, 'Transformed x_:', x_, 'Transformed y_:', y_)
# Out:
# Index:  0 Original x:  tensor([2., 2.]) Original y:  tensor([1.])
# Index:  0 Transformed x_: tensor([3., 3.]) Transformed y_: tensor([2.])
# Index:  1 Original x:  tensor([2., 2.]) Original y:  tensor([1.])
# Index:  1 Transformed x_: tensor([3., 3.]) Transformed y_: tensor([2.])
# Index:  2 Original x:  tensor([2., 2.]) Original y:  tensor([1.])
# Index:  2 Transformed x_: tensor([3., 3.]) Transformed y_: tensor([2.])
# Index:  3 Original x:  tensor([2., 2.]) Original y:  tensor([1.])
# Index:  3 Transformed x_: tensor([3., 3.]) Transformed y_: tensor([2.])
# Index:  4 Original x:  tensor([2., 2.]) Original y:  tensor([1.])
# Index:  4 Transformed x_: tensor([3., 3.]) Transformed y_: tensor([2.])
# Index:  5 Original x:  tensor([2., 2.]) Original y:  tensor([1.])
# Index:  5 Transformed x_: tensor([3., 3.]) Transformed y_: tensor([2.])
# Index:  6 Original x:  tensor([2., 2.]) Original y:  tensor([1.])
# Index:  6 Transformed x_: tensor([3., 3.]) Transformed y_: tensor([2.])
# Index:  7 Original x:  tensor([2., 2.]) Original y:  tensor([1.])
# Index:  7 Transformed x_: tensor([3., 3.]) Transformed y_: tensor([2.])
# Index:  8 Original x:  tensor([2., 2.]) Original y:  tensor([1.])
# Index:  8 Transformed x_: tensor([3., 3.]) Transformed y_: tensor([2.])
# Index:  9 Original x:  tensor([2., 2.]) Original y:  tensor([1.])
# Index:  9 Transformed x_: tensor([3., 3.]) Transformed y_: tensor([2.])

# %% [markdown]
# The result is the same as the previous method.

# %% [markdown]
# <!--Empty Space for separating topics-->

# %%
# Practice: Construct your own my_add_mult transform. Apply my_add_mult on a new toy_set object. Print out the first three elements from the transformed dataset.

class my_add_mult(object):
    
    
    def __init__(self,addx,muly):
        
        self.addx = addx
        self.muly = muly
        
    
    def __call__(self,sample):
        
        x = sample[0]
        y=  sample[1]
        
        x = x + self.addx
        y = y * self.muly
        
        return x,y
        
        
        
add_mult_object = my_add_mult(1,2)
 
new_dataset = toy_set(transform=add_mult_object)


for i in range( len(data_set)):
    
    x,y= data_set[i]
    print(f"Original x: {x}, y: {y}")
    
    x_,y_ = new_dataset[i]
    print(f"Updated x: {x_}, y: {y_}")
# Out:
# Original x: tensor([2., 2.]), y: tensor([1.])
# Updated x: tensor([3., 3.]), y: tensor([2.])
# Original x: tensor([2., 2.]), y: tensor([1.])
# Updated x: tensor([3., 3.]), y: tensor([2.])
# Original x: tensor([2., 2.]), y: tensor([1.])
# Updated x: tensor([3., 3.]), y: tensor([2.])
# Original x: tensor([2., 2.]), y: tensor([1.])
# Updated x: tensor([3., 3.]), y: tensor([2.])
# Original x: tensor([2., 2.]), y: tensor([1.])
# Updated x: tensor([3., 3.]), y: tensor([2.])
# Original x: tensor([2., 2.]), y: tensor([1.])
# Updated x: tensor([3., 3.]), y: tensor([2.])
# Original x: tensor([2., 2.]), y: tensor([1.])
# Updated x: tensor([3., 3.]), y: tensor([2.])
# Original x: tensor([2., 2.]), y: tensor([1.])
# Updated x: tensor([3., 3.]), y: tensor([2.])
# Original x: tensor([2., 2.]), y: tensor([1.])
# Updated x: tensor([3., 3.]), y: tensor([2.])
# Original x: tensor([2., 2.]), y: tensor([1.])
# Updated x: tensor([3., 3.]), y: tensor([2.])
# Original x: tensor([2., 2.]), y: tensor([1.])
# Updated x: tensor([3., 3.]), y: tensor([2.])
# Original x: tensor([2., 2.]), y: tensor([1.])
# Updated x: tensor([3., 3.]), y: tensor([2.])
# Original x: tensor([2., 2.]), y: tensor([1.])
# Updated x: tensor([3., 3.]), y: tensor([2.])
# Original x: tensor([2., 2.]), y: tensor([1.])
# Updated x: tensor([3., 3.]), y: tensor([2.])
# Original x: tensor([2., 2.]), y: tensor([1.])
# Updated x: tensor([3., 3.]), y: tensor([2.])
# Original x: tensor([2., 2.]), y: tensor([1.])
# Updated x: tensor([3., 3.]), y: tensor([2.])
# Original x: tensor([2., 2.]), y: tensor([1.])
# Updated x: tensor([3., 3.]), y: tensor([2.])
# Original x: tensor([2., 2.]), y: tensor([1.])
# Updated x: tensor([3., 3.]), y: tensor([2.])
# Original x: tensor([2., 2.]), y: tensor([1.])
# Updated x: tensor([3., 3.]), y: tensor([2.])
# Original x: tensor([2., 2.]), y: tensor([1.])
# Updated x: tensor([3., 3.]), y: tensor([2.])
# Original x: tensor([2., 2.]), y: tensor([1.])
# Updated x: tensor([3., 3.]), y: tensor([2.])
# Original x: tensor([2., 2.]), y: tensor([1.])
# Updated x: tensor([3., 3.]), y: tensor([2.])
# Original x: tensor([2., 2.]), y: tensor([1.])
# Updated x: tensor([3., 3.]), y: tensor([2.])
# Original x: tensor([2., 2.]), y: tensor([1.])
# Updated x: tensor([3., 3.]), y: tensor([2.])
# Original x: tensor([2., 2.]), y: tensor([1.])
# Updated x: tensor([3., 3.]), y: tensor([2.])
# Original x: tensor([2., 2.]), y: tensor([1.])
# Updated x: tensor([3., 3.]), y: tensor([2.])
# Original x: tensor([2., 2.]), y: tensor([1.])
# Updated x: tensor([3., 3.]), y: tensor([2.])
# Original x: tensor([2., 2.]), y: tensor([1.])
# Updated x: tensor([3., 3.]), y: tensor([2.])
# Original x: tensor([2., 2.]), y: tensor([1.])
# Updated x: tensor([3., 3.]), y: tensor([2.])
# Original x: tensor([2., 2.]), y: tensor([1.])
# Updated x: tensor([3., 3.]), y: tensor([2.])
# Original x: tensor([2., 2.]), y: tensor([1.])
# Updated x: tensor([3., 3.]), y: tensor([2.])
# Original x: tensor([2., 2.]), y: tensor([1.])
# Updated x: tensor([3., 3.]), y: tensor([2.])
# Original x: tensor([2., 2.]), y: tensor([1.])
# Updated x: tensor([3., 3.]), y: tensor([2.])
# Original x: tensor([2., 2.]), y: tensor([1.])
# Updated x: tensor([3., 3.]), y: tensor([2.])
# Original x: tensor([2., 2.]), y: tensor([1.])
# Updated x: tensor([3., 3.]), y: tensor([2.])
# Original x: tensor([2., 2.]), y: tensor([1.])
# Updated x: tensor([3., 3.]), y: tensor([2.])
# Original x: tensor([2., 2.]), y: tensor([1.])
# Updated x: tensor([3., 3.]), y: tensor([2.])
# Original x: tensor([2., 2.]), y: tensor([1.])
# Updated x: tensor([3., 3.]), y: tensor([2.])
# Original x: tensor([2., 2.]), y: tensor([1.])
# Updated x: tensor([3., 3.]), y: tensor([2.])
# Original x: tensor([2., 2.]), y: tensor([1.])
# Updated x: tensor([3., 3.]), y: tensor([2.])
# Original x: tensor([2., 2.]), y: tensor([1.])
# Updated x: tensor([3., 3.]), y: tensor([2.])
# Original x: tensor([2., 2.]), y: tensor([1.])
# Updated x: tensor([3., 3.]), y: tensor([2.])
# Original x: tensor([2., 2.]), y: tensor([1.])
# Updated x: tensor([3., 3.]), y: tensor([2.])
# Original x: tensor([2., 2.]), y: tensor([1.])
# Updated x: tensor([3., 3.]), y: tensor([2.])
# Original x: tensor([2., 2.]), y: tensor([1.])
# Updated x: tensor([3., 3.]), y: tensor([2.])
# Original x: tensor([2., 2.]), y: tensor([1.])
# Updated x: tensor([3., 3.]), y: tensor([2.])
# Original x: tensor([2., 2.]), y: tensor([1.])
# Updated x: tensor([3., 3.]), y: tensor([2.])
# Original x: tensor([2., 2.]), y: tensor([1.])
# Updated x: tensor([3., 3.]), y: tensor([2.])
# Original x: tensor([2., 2.]), y: tensor([1.])
# Updated x: tensor([3., 3.]), y: tensor([2.])
# Original x: tensor([2., 2.]), y: tensor([1.])
# Updated x: tensor([3., 3.]), y: tensor([2.])

# %% [markdown]
# Double-click <b>here</b> for the solution.
# <!--
# class my_add_mult(object):
#     def __init__(self, add = 2, mul = 10):
#         self.add=add
#         self.mul=mul
#
#     def __call__(self, sample):
#         x = sample[0]
#         y = sample[1]
#         x = x + self.add
#         y = y + self.add
#         x = x * self.mul
#         y = y * self.mul
#         sample = x, y
#         return sample
#
#
# my_dataset = toy_set(transform = my_add_mult())
# for i in range(3):
#     x_, y_ = my_dataset[i]
#     print('Index: ', i, 'Transformed x_:', x_, 'Transformed y_:', y_)
#
#  -->

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="Compose">Compose</h2>

# %% [markdown]
# You can compose multiple transforms on the dataset object. First, import <code>transforms</code> from <code>torchvision</code>:

# %%
# Run the command below when you do not have torchvision installed
# !mamba install -y torchvision

from torchvision import transforms

# %% [markdown]
# Then, create a new transform class that multiplies each of the elements by 100:

# %%
# Create tranform class mult

class mult(object):
    
    # Constructor
    def __init__(self, mult = 100):
        self.mult = mult
        
    # Executor
    def __call__(self, sample):
        x = sample[0]
        y = sample[1]
        x = x * self.mult
        y = y * self.mult
        sample = x, y
        return sample

# %% [markdown]
# Now let us try to combine the transforms <code>add_mult</code> and <code>mult</code>

# %%
# Combine the add_mult() and mult()

data_transform = transforms.Compose([add_mult(), mult()])
print("The combination of transforms (Compose): ", data_transform)
# Out:
# The combination of transforms (Compose):  Compose(
#     <__main__.add_mult object at 0x0000025DF4D1B200>
#     <__main__.mult object at 0x0000025DF4D1B050>
# )

# %% [markdown]
# The new <code>Compose</code> object will perform each transform concurrently as shown in this figure:

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0110EN/notebook_images%20/chapter%201/1.3.1_trasform.png" width="500" alt="Compose PyTorch">

# %%
data_transform(data_set[0])
# Out:
# (tensor([300., 300.]), tensor([200.]))

# %%
x,y=data_set[0]
x_,y_=data_transform(data_set[0])
print( 'Original x: ', x, 'Original y: ', y)

print( 'Transformed x_:', x_, 'Transformed y_:', y_)
# Out:
# Original x:  tensor([2., 2.]) Original y:  tensor([1.])
# Transformed x_: tensor([300., 300.]) Transformed y_: tensor([200.])

# %% [markdown]
# Now we can pass the new <code>Compose</code> object (The combination of methods <code>add_mult()</code> and <code>mult</code>) to the constructor for creating <code>toy_set</code> object.

# %%
# Create a new toy_set object with compose object as transform

compose_data_set = toy_set(transform = data_transform)

# %% [markdown]
# Let us print out the first 3 elements in different <code>toy_set</code> datasets in order to compare the output after different transforms have been applied:

# %%
# Use loop to print out first 3 elements in dataset

for i in range(3):
    x, y = data_set[i]
    print('Index: ', i, 'Original x: ', x, 'Original y: ', y)
    x_, y_ = cust_data_set[i]
    print('Index: ', i, 'Transformed x_:', x_, 'Transformed y_:', y_)
    x_co, y_co = compose_data_set[i]
    print('Index: ', i, 'Compose Transformed x_co: ', x_co ,'Compose Transformed y_co: ',y_co)
# Out:
# Index:  0 Original x:  tensor([2., 2.]) Original y:  tensor([1.])
# Index:  0 Transformed x_: tensor([3., 3.]) Transformed y_: tensor([2.])
# Index:  0 Compose Transformed x_co:  tensor([300., 300.]) Compose Transformed y_co:  tensor([200.])
# Index:  1 Original x:  tensor([2., 2.]) Original y:  tensor([1.])
# Index:  1 Transformed x_: tensor([3., 3.]) Transformed y_: tensor([2.])
# Index:  1 Compose Transformed x_co:  tensor([300., 300.]) Compose Transformed y_co:  tensor([200.])
# Index:  2 Original x:  tensor([2., 2.]) Original y:  tensor([1.])
# Index:  2 Transformed x_: tensor([3., 3.]) Transformed y_: tensor([2.])
# Index:  2 Compose Transformed x_co:  tensor([300., 300.]) Compose Transformed y_co:  tensor([200.])

# %% [markdown]
# Let us see what happened on index 0. The original value of <code>x</code> is <i>[2, 2]</i>, and the original value of <code>y</code> is [1]. If we only applied <code>add_mult()</code> on the original dataset, then the <code>x</code> became <i>[3, 3]</i> and y became <i>[2]</i>. Now let us see what is the value after applied both <code>add_mult()</code> and <code>mult()</code>. The result of x is <i>[300, 300]</i> and y is <i>[200]</i>. The calculation which is equavalent to the compose is <i> x = ([2, 2] + 1) x 100 = [300, 300], y = ([1] x 2) x 100 = 200</i>

# %% [markdown]
# <h3>Practice</h3>

# %% [markdown]
# Try to combine the <code>mult()</code> and <code>add_mult()</code> as <code>mult()</code> to be executed first. And apply this on a new <code>toy_set</code> dataset. Print out the first 3 elements in the transformed dataset.

# %%
# Practice: Make a compose as mult() execute first and then add_mult(). Apply the compose on toy_set dataset. Print out the first 3 elements in the transformed dataset.

# Type your code here.

# %% [markdown]
# Double-click <b>here</b> for the solution.
# <!--
# my_compose = transforms.Compose([mult(), add_mult()])
# my_transformed_dataset = toy_set(transform = my_compose)
# for i in range(3):
#     x_, y_ = my_transformed_dataset[i]
#     print('Index: ', i, 'Transformed x_:', x_, 'Transformed y_:', y_)
# -->

# %% [markdown]
# <h2>About the Authors:</h2>
#
# <a href="https://www.linkedin.com/in/joseph-s-50398b136/">Joseph Santarcangelo</a> has a PhD in Electrical Engineering, his research focused on using machine learning, signal processing, and computer vision to determine how videos impact human cognition. Joseph has been working for IBM since he completed his PhD.

# %% [markdown]
# Other contributors: <a href="https://www.linkedin.com/in/michelleccarey/">Michelle Carey</a>, <a href="www.linkedin.com/in/jiahui-mavis-zhou-a4537814a">Mavis Zhou</a>

# %% [markdown]
# <!--
# ## Change Log
#
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2020-09-21  | 2.0  | Shubham  |  Migrated Lab to Markdown and added to course repo in GitLab |
#
# -->

# %% [markdown]
# <hr>

# %% [markdown]
# ## <h3 align="center"> &#169; IBM Corporation. All rights reserved. <h3/>
