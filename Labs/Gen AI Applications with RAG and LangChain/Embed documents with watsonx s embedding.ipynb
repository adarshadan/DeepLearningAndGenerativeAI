# %% [markdown]
# # **Embed documents using watsonx's embedding model**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# ## Overview

# %% [markdown]
# Imagine you work in a company that handles a vast amount of text data, including documents, emails, and reports. Your task is to build an intelligent search system that can quickly and accurately retrieve relevant documents based on user queries. Traditional keyword-based search methods often fail to understand the context and semantics of the queries, leading to poor search results.
#
# To address this challenge, you can use embedding models to convert documents into numerical vectors. These vectors capture the semantic meaning of the text, enabling more accurate and context-aware search capabilities. Document embedding is a powerful technique to convert textual data into numerical vectors, which can then be used for various downstream tasks such as search, classification, clustering, and more.

# %% [markdown]
# In this lab, you will learn how to use embedding models from watsonx.ai and Hugging Face to embed documents. By the end of this lab, you will be able to effectively use these embedding models to transform and utilize textual data in your projects.

# %% [markdown]
# ## __Table of Contents__
#
# <ol>
#     <li><a href="#Objectives">Objectives</a></li>
#     <li>
#         <a href="#Setup">Setup</a>
#         <ol>
#             <li><a href="#Installing-required-ribraries">Installing required libraries</a></li>
#             <li><a href="#Load-data">Load data</a></li>
#             <li><a href="#Split data">Split data</a></li>
#         </ol>
#     </li>
#     <li>
#         <a href="#Watsonx-embedding-model">Watsonx embedding model</a>
#         <ol>
#             <li><a href="#Model-description">Model description</a></li>
#             <li><a href="#Build-model">Build model</a></li>
#             <li><a href="#Query-embeddings">Query embeddings</a></li>
#             <li><a href="#Document-embeddings">Document embeddings</a></li>
#         </ol>
#     </li>
#     <li>
#         <a href="#HuggingFace embedding model">HuggingFace embedding models</a>
#         <ol>
#             <li><a href="#Model-description">Model description</a></li>
#             <li><a href="#Build-model">Build model</a></li>
#             <li><a href="#Query-embeddings">Query embeddings</a></li>
#             <li><a href="#Document-embeddings">Document embeddings</a></li>
#         </ol>
#     </li>
# </ol>
#
# <a href="#Exercises">Exercises</a>
# <ol>
#     <li><a href="#Exercise-1---Using-another-watsonx-embedding-model">Exercise 1. Using another watsonx embedding model</a></li>
# </ol>

# %% [markdown]
# ## Objectives
#
# After completing this lab, you will be able to:
#
#  - Prepare and preprocess documents for embedding
#  - Use watsonx.ai and Hugging Face embedding models to generate embeddings for your documents

# %% [markdown]
# ----

# %% [markdown]
# ## Setup

# %% [markdown]
# For this lab, you will use the following libraries:
#
# * [`ibm-watson-ai`](https://ibm.github.io/watsonx-ai-python-sdk/fm_embeddings.html#EmbeddingModels) for using embedding models from IBM's watsonx.ai.
# * [`langchain`, `langchain-ibm`, `langchain-community`](https://www.langchain.com/) for using relevant features from LangChain.
# * [`sentence-transformers`](https://huggingface.co/sentence-transformers) for using embedding models from HuggingFace.

# %% [markdown]
# ### Installing required libraries
#
# The following required libraries are __not__ preinstalled in the Skills Network Labs environment. __You need to run the following cell__ to install them:
#
# **Note:** The version is being pinned here to specify the version. It's recommended that you do this as well. Even if the library is updated in the future, the installed library could still support this lab work.
#
# This might take around 1-2 minutes.
#
# As `%%capture` is used to capture the installation, you won't see the output process. But after the installation completes, you will see a number beside the cell.

# %%
#%%capture
#After executing the cell,please RESTART the kernel and run all the cells.
# !pip install --user "ibm-watsonx-ai==1.1.2"
# !pip install --user "langchain==0.2.11"
# !pip install --user "langchain-ibm==0.1.11"
# !pip install --user "langchain-community==0.2.10"
# !pip install --user "sentence-transformers==3.0.1"
# Out:
# Requirement already satisfied: ibm-watsonx-ai==1.1.2 in /home/jupyterlab/.local/lib/python3.12/site-packages (1.1.2)
# Requirement already satisfied: requests in /home/jupyterlab/.local/lib/python3.12/site-packages (from ibm-watsonx-ai==1.1.2) (2.32.2)
# Requirement already satisfied: urllib3 in /opt/conda/lib/python3.12/site-packages (from ibm-watsonx-ai==1.1.2) (2.3.0)
# Requirement already satisfied: pandas<2.2.0,>=0.24.2 in /home/jupyterlab/.local/lib/python3.12/site-packages (from ibm-watsonx-ai==1.1.2) (2.1.4)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.12/site-packages (from ibm-watsonx-ai==1.1.2) (2024.12.14)
# Requirement already satisfied: lomond in /home/jupyterlab/.local/lib/python3.12/site-packages (from ibm-watsonx-ai==1.1.2) (0.3.3)
# Requirement already satisfied: tabulate in /home/jupyterlab/.local/lib/python3.12/site-packages (from ibm-watsonx-ai==1.1.2) (0.10.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.12/site-packages (from ibm-watsonx-ai==1.1.2) (24.2)
# Requirement already satisfied: ibm-cos-sdk<2.14.0,>=2.12.0 in /home/jupyterlab/.local/lib/python3.12/site-packages (from ibm-watsonx-ai==1.1.2) (2.13.6)
# Requirement already satisfied: importlib-metadata in /opt/conda/lib/python3.12/site-packages (from ibm-watsonx-ai==1.1.2) (8.6.1)
# Requirement already satisfied: ibm-cos-sdk-core==2.13.6 in /home/jupyterlab/.local/lib/python3.12/site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai==1.1.2) (2.13.6)
# Requirement already satisfied: ibm-cos-sdk-s3transfer==2.13.6 in /home/jupyterlab/.local/lib/python3.12/site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai==1.1.2) (2.13.6)
# Requirement already satisfied: jmespath<=1.0.1,>=0.10.0 in /home/jupyterlab/.local/lib/python3.12/site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai==1.1.2) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.9.0 in /opt/conda/lib/python3.12/site-packages (from ibm-cos-sdk-core==2.13.6->ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai==1.1.2) (2.9.0.post0)
# Requirement already satisfied: numpy<2,>=1.26.0 in /home/jupyterlab/.local/lib/python3.12/site-packages (from pandas<2.2.0,>=0.24.2->ibm-watsonx-ai==1.1.2) (1.26.4)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas<2.2.0,>=0.24.2->ibm-watsonx-ai==1.1.2) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /home/jupyterlab/.local/lib/python3.12/site-packages (from pandas<2.2.0,>=0.24.2->ibm-watsonx-ai==1.1.2) (2026.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests->ibm-watsonx-ai==1.1.2) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests->ibm-watsonx-ai==1.1.2) (3.10)
# Requirement already satisfied: zipp>=3.20 in /opt/conda/lib/python3.12/site-packages (from importlib-metadata->ibm-watsonx-ai==1.1.2) (3.21.0)
# Requirement already satisfied: six>=1.10.0 in /opt/conda/lib/python3.12/site-packages (from lomond->ibm-watsonx-ai==1.1.2) (1.17.0)
# Requirement already satisfied: langchain==0.2.11 in /home/jupyterlab/.local/lib/python3.12/site-packages (0.2.11)
# Requirement already satisfied: PyYAML>=5.3 in /opt/conda/lib/python3.12/site-packages (from langchain==0.2.11) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /opt/conda/lib/python3.12/site-packages (from langchain==0.2.11) (2.0.37)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/conda/lib/python3.12/site-packages (from langchain==0.2.11) (3.11.18)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.23 in /home/jupyterlab/.local/lib/python3.12/site-packages (from langchain==0.2.11) (0.2.43)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in /home/jupyterlab/.local/lib/python3.12/site-packages (from langchain==0.2.11) (0.2.4)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /home/jupyterlab/.local/lib/python3.12/site-packages (from langchain==0.2.11) (0.1.147)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in /home/jupyterlab/.local/lib/python3.12/site-packages (from langchain==0.2.11) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in /opt/conda/lib/python3.12/site-packages (from langchain==0.2.11) (2.10.6)
# Requirement already satisfied: requests<3,>=2 in /home/jupyterlab/.local/lib/python3.12/site-packages (from langchain==0.2.11) (2.32.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /home/jupyterlab/.local/lib/python3.12/site-packages (from langchain==0.2.11) (8.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.11) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.11) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.11) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.11) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.11) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.11) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.11) (1.20.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/conda/lib/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.23->langchain==0.2.11) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /opt/conda/lib/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.23->langchain==0.2.11) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /opt/conda/lib/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.23->langchain==0.2.11) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/conda/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.2.11) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/jupyterlab/.local/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.2.11) (3.11.9)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/jupyterlab/.local/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.2.11) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.12/site-packages (from pydantic<3,>=1->langchain==0.2.11) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /opt/conda/lib/python3.12/site-packages (from pydantic<3,>=1->langchain==0.2.11) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2->langchain==0.2.11) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2->langchain==0.2.11) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2->langchain==0.2.11) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2->langchain==0.2.11) (2024.12.14)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.12/site-packages (from SQLAlchemy<3,>=1.4->langchain==0.2.11) (3.1.1)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.2.11) (4.8.0)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.2.11) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.2.11) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/conda/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.23->langchain==0.2.11) (3.0.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.12/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.2.11) (1.3.1)
# Requirement already satisfied: langchain-ibm==0.1.11 in /home/jupyterlab/.local/lib/python3.12/site-packages (0.1.11)
# Requirement already satisfied: ibm-watsonx-ai<2.0.0,>=1.0.8 in /home/jupyterlab/.local/lib/python3.12/site-packages (from langchain-ibm==0.1.11) (1.1.2)
# Requirement already satisfied: langchain-core<0.3,>=0.2.2 in /home/jupyterlab/.local/lib/python3.12/site-packages (from langchain-ibm==0.1.11) (0.2.43)
# Requirement already satisfied: requests in /home/jupyterlab/.local/lib/python3.12/site-packages (from ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.11) (2.32.2)
# Requirement already satisfied: urllib3 in /opt/conda/lib/python3.12/site-packages (from ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.11) (2.3.0)
# Requirement already satisfied: pandas<2.2.0,>=0.24.2 in /home/jupyterlab/.local/lib/python3.12/site-packages (from ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.11) (2.1.4)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.12/site-packages (from ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.11) (2024.12.14)
# Requirement already satisfied: lomond in /home/jupyterlab/.local/lib/python3.12/site-packages (from ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.11) (0.3.3)
# Requirement already satisfied: tabulate in /home/jupyterlab/.local/lib/python3.12/site-packages (from ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.11) (0.10.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.12/site-packages (from ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.11) (24.2)
# Requirement already satisfied: ibm-cos-sdk<2.14.0,>=2.12.0 in /home/jupyterlab/.local/lib/python3.12/site-packages (from ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.11) (2.13.6)
# Requirement already satisfied: importlib-metadata in /opt/conda/lib/python3.12/site-packages (from ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.11) (8.6.1)
# Requirement already satisfied: PyYAML>=5.3 in /opt/conda/lib/python3.12/site-packages (from langchain-core<0.3,>=0.2.2->langchain-ibm==0.1.11) (6.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/conda/lib/python3.12/site-packages (from langchain-core<0.3,>=0.2.2->langchain-ibm==0.1.11) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.112 in /home/jupyterlab/.local/lib/python3.12/site-packages (from langchain-core<0.3,>=0.2.2->langchain-ibm==0.1.11) (0.1.147)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /opt/conda/lib/python3.12/site-packages (from langchain-core<0.3,>=0.2.2->langchain-ibm==0.1.11) (2.10.6)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /home/jupyterlab/.local/lib/python3.12/site-packages (from langchain-core<0.3,>=0.2.2->langchain-ibm==0.1.11) (8.5.0)
# Requirement already satisfied: typing-extensions>=4.7 in /opt/conda/lib/python3.12/site-packages (from langchain-core<0.3,>=0.2.2->langchain-ibm==0.1.11) (4.12.2)
# Requirement already satisfied: ibm-cos-sdk-core==2.13.6 in /home/jupyterlab/.local/lib/python3.12/site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.11) (2.13.6)
# Requirement already satisfied: ibm-cos-sdk-s3transfer==2.13.6 in /home/jupyterlab/.local/lib/python3.12/site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.11) (2.13.6)
# Requirement already satisfied: jmespath<=1.0.1,>=0.10.0 in /home/jupyterlab/.local/lib/python3.12/site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.11) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.9.0 in /opt/conda/lib/python3.12/site-packages (from ibm-cos-sdk-core==2.13.6->ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.11) (2.9.0.post0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/conda/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3,>=0.2.2->langchain-ibm==0.1.11) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/conda/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.2.2->langchain-ibm==0.1.11) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/jupyterlab/.local/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.2.2->langchain-ibm==0.1.11) (3.11.9)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/jupyterlab/.local/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.2.2->langchain-ibm==0.1.11) (1.0.0)
# Requirement already satisfied: numpy<2,>=1.26.0 in /home/jupyterlab/.local/lib/python3.12/site-packages (from pandas<2.2.0,>=0.24.2->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.11) (1.26.4)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas<2.2.0,>=0.24.2->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.11) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /home/jupyterlab/.local/lib/python3.12/site-packages (from pandas<2.2.0,>=0.24.2->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.11) (2026.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.3,>=0.2.2->langchain-ibm==0.1.11) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /opt/conda/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.3,>=0.2.2->langchain-ibm==0.1.11) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.11) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.11) (3.10)
# Requirement already satisfied: zipp>=3.20 in /opt/conda/lib/python3.12/site-packages (from importlib-metadata->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.11) (3.21.0)
# Requirement already satisfied: six>=1.10.0 in /opt/conda/lib/python3.12/site-packages (from lomond->ibm-watsonx-ai<2.0.0,>=1.0.8->langchain-ibm==0.1.11) (1.17.0)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.2.2->langchain-ibm==0.1.11) (4.8.0)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.2.2->langchain-ibm==0.1.11) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.2.2->langchain-ibm==0.1.11) (0.14.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.12/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.2.2->langchain-ibm==0.1.11) (1.3.1)
# Requirement already satisfied: langchain-community==0.2.10 in /home/jupyterlab/.local/lib/python3.12/site-packages (0.2.10)
# Requirement already satisfied: PyYAML>=5.3 in /opt/conda/lib/python3.12/site-packages (from langchain-community==0.2.10) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /opt/conda/lib/python3.12/site-packages (from langchain-community==0.2.10) (2.0.37)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/conda/lib/python3.12/site-packages (from langchain-community==0.2.10) (3.11.18)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /home/jupyterlab/.local/lib/python3.12/site-packages (from langchain-community==0.2.10) (0.6.7)
# Requirement already satisfied: langchain<0.3.0,>=0.2.9 in /home/jupyterlab/.local/lib/python3.12/site-packages (from langchain-community==0.2.10) (0.2.11)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.23 in /home/jupyterlab/.local/lib/python3.12/site-packages (from langchain-community==0.2.10) (0.2.43)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in /home/jupyterlab/.local/lib/python3.12/site-packages (from langchain-community==0.2.10) (0.1.147)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in /home/jupyterlab/.local/lib/python3.12/site-packages (from langchain-community==0.2.10) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in /home/jupyterlab/.local/lib/python3.12/site-packages (from langchain-community==0.2.10) (2.32.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /home/jupyterlab/.local/lib/python3.12/site-packages (from langchain-community==0.2.10) (8.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.2.10) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.2.10) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.2.10) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.2.10) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.2.10) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.2.10) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.2.10) (1.20.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/jupyterlab/.local/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.2.10) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/jupyterlab/.local/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.2.10) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in /home/jupyterlab/.local/lib/python3.12/site-packages (from langchain<0.3.0,>=0.2.9->langchain-community==0.2.10) (0.2.4)
# Requirement already satisfied: pydantic<3,>=1 in /opt/conda/lib/python3.12/site-packages (from langchain<0.3.0,>=0.2.9->langchain-community==0.2.10) (2.10.6)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/conda/lib/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.23->langchain-community==0.2.10) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /opt/conda/lib/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.23->langchain-community==0.2.10) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /opt/conda/lib/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.23->langchain-community==0.2.10) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/conda/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.0->langchain-community==0.2.10) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/jupyterlab/.local/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.0->langchain-community==0.2.10) (3.11.9)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/jupyterlab/.local/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.0->langchain-community==0.2.10) (1.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2->langchain-community==0.2.10) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2->langchain-community==0.2.10) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2->langchain-community==0.2.10) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2->langchain-community==0.2.10) (2024.12.14)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.12/site-packages (from SQLAlchemy<3,>=1.4->langchain-community==0.2.10) (3.1.1)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community==0.2.10) (4.8.0)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community==0.2.10) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community==0.2.10) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/conda/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.23->langchain-community==0.2.10) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.12/site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.9->langchain-community==0.2.10) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /opt/conda/lib/python3.12/site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.9->langchain-community==0.2.10) (2.27.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/jupyterlab/.local/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community==0.2.10) (1.1.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.12/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community==0.2.10) (1.3.1)
# Requirement already satisfied: sentence-transformers==3.0.1 in /home/jupyterlab/.local/lib/python3.12/site-packages (3.0.1)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /home/jupyterlab/.local/lib/python3.12/site-packages (from sentence-transformers==3.0.1) (4.57.6)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.12/site-packages (from sentence-transformers==3.0.1) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /home/jupyterlab/.local/lib/python3.12/site-packages (from sentence-transformers==3.0.1) (2.12.0)
# Requirement already satisfied: numpy in /home/jupyterlab/.local/lib/python3.12/site-packages (from sentence-transformers==3.0.1) (1.26.4)
# Requirement already satisfied: scikit-learn in /home/jupyterlab/.local/lib/python3.12/site-packages (from sentence-transformers==3.0.1) (1.9.0)
# Requirement already satisfied: scipy in /home/jupyterlab/.local/lib/python3.12/site-packages (from sentence-transformers==3.0.1) (1.17.1)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /home/jupyterlab/.local/lib/python3.12/site-packages (from sentence-transformers==3.0.1) (0.36.2)
# Requirement already satisfied: Pillow in /home/jupyterlab/.local/lib/python3.12/site-packages (from sentence-transformers==3.0.1) (12.2.0)
# Requirement already satisfied: filelock in /home/jupyterlab/.local/lib/python3.12/site-packages (from huggingface-hub>=0.15.1->sentence-transformers==3.0.1) (3.29.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/jupyterlab/.local/lib/python3.12/site-packages (from huggingface-hub>=0.15.1->sentence-transformers==3.0.1) (2026.4.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/jupyterlab/.local/lib/python3.12/site-packages (from huggingface-hub>=0.15.1->sentence-transformers==3.0.1) (1.5.0)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.12/site-packages (from huggingface-hub>=0.15.1->sentence-transformers==3.0.1) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.12/site-packages (from huggingface-hub>=0.15.1->sentence-transformers==3.0.1) (6.0.2)
# Requirement already satisfied: requests in /home/jupyterlab/.local/lib/python3.12/site-packages (from huggingface-hub>=0.15.1->sentence-transformers==3.0.1) (2.32.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.12/site-packages (from huggingface-hub>=0.15.1->sentence-transformers==3.0.1) (4.12.2)
# Requirement already satisfied: setuptools<82 in /opt/conda/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (75.8.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/jupyterlab/.local/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/jupyterlab/.local/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (3.6.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (3.1.5)
# Requirement already satisfied: cuda-toolkit==13.0.2 in /home/jupyterlab/.local/lib/python3.12/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.11.0->sentence-transformers==3.0.1) (13.0.2)
# Requirement already satisfied: nvidia-cublas<=13.1.1.3,>=13.1.0.3 in /home/jupyterlab/.local/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (13.1.1.3)
# Requirement already satisfied: cuda-bindings<14,>=13.0.3 in /home/jupyterlab/.local/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (13.3.1)
# Requirement already satisfied: nvidia-cudnn-cu13==9.20.0.48 in /home/jupyterlab/.local/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (9.20.0.48)
# Requirement already satisfied: nvidia-cusparselt-cu13==0.8.1 in /home/jupyterlab/.local/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (0.8.1)
# Requirement already satisfied: nvidia-nccl-cu13==2.29.7 in /home/jupyterlab/.local/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (2.29.7)
# Requirement already satisfied: nvidia-nvshmem-cu13==3.4.5 in /home/jupyterlab/.local/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (3.4.5)
# Requirement already satisfied: triton==3.7.0 in /home/jupyterlab/.local/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers==3.0.1) (3.7.0)
# Requirement already satisfied: nvidia-cuda-runtime==13.0.96.* in /home/jupyterlab/.local/lib/python3.12/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.11.0->sentence-transformers==3.0.1) (13.0.96)
# Requirement already satisfied: nvidia-cufft==12.0.0.61.* in /home/jupyterlab/.local/lib/python3.12/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.11.0->sentence-transformers==3.0.1) (12.0.0.61)
# Requirement already satisfied: nvidia-cufile==1.15.1.6.* in /home/jupyterlab/.local/lib/python3.12/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.11.0->sentence-transformers==3.0.1) (1.15.1.6)
# Requirement already satisfied: nvidia-cuda-cupti==13.0.85.* in /home/jupyterlab/.local/lib/python3.12/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.11.0->sentence-transformers==3.0.1) (13.0.85)
# Requirement already satisfied: nvidia-curand==10.4.0.35.* in /home/jupyterlab/.local/lib/python3.12/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.11.0->sentence-transformers==3.0.1) (10.4.0.35)
# Requirement already satisfied: nvidia-cusolver==12.0.4.66.* in /home/jupyterlab/.local/lib/python3.12/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.11.0->sentence-transformers==3.0.1) (12.0.4.66)
# Requirement already satisfied: nvidia-cusparse==12.6.3.3.* in /home/jupyterlab/.local/lib/python3.12/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.11.0->sentence-transformers==3.0.1) (12.6.3.3)
# Requirement already satisfied: nvidia-nvjitlink==13.0.88.* in /home/jupyterlab/.local/lib/python3.12/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.11.0->sentence-transformers==3.0.1) (13.0.88)
# Requirement already satisfied: nvidia-cuda-nvrtc==13.0.88.* in /home/jupyterlab/.local/lib/python3.12/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.11.0->sentence-transformers==3.0.1) (13.0.88)
# Requirement already satisfied: nvidia-nvtx==13.0.85.* in /home/jupyterlab/.local/lib/python3.12/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.11.0->sentence-transformers==3.0.1) (13.0.85)
# Requirement already satisfied: regex!=2019.12.17 in /home/jupyterlab/.local/lib/python3.12/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers==3.0.1) (2026.5.9)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /home/jupyterlab/.local/lib/python3.12/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers==3.0.1) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /home/jupyterlab/.local/lib/python3.12/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers==3.0.1) (0.7.0)
# Requirement already satisfied: joblib>=1.4.0 in /home/jupyterlab/.local/lib/python3.12/site-packages (from scikit-learn->sentence-transformers==3.0.1) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in /home/jupyterlab/.local/lib/python3.12/site-packages (from scikit-learn->sentence-transformers==3.0.1) (2.22.1)
# Requirement already satisfied: threadpoolctl>=3.5.0 in /home/jupyterlab/.local/lib/python3.12/site-packages (from scikit-learn->sentence-transformers==3.0.1) (3.6.0)
# Requirement already satisfied: cuda-pathfinder>=1.4.2 in /home/jupyterlab/.local/lib/python3.12/site-packages (from cuda-bindings<14,>=13.0.3->torch>=1.11.0->sentence-transformers==3.0.1) (1.5.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/jupyterlab/.local/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers==3.0.1) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.12/site-packages (from jinja2->torch>=1.11.0->sentence-transformers==3.0.1) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers==3.0.1) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers==3.0.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers==3.0.1) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers==3.0.1) (2024.12.14)

# %%
# %pip install uv
# Out:
# Requirement already satisfied: uv in /opt/conda/lib/python3.12/site-packages (0.11.19)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %uv pip install pypdf
# Out:
# Using Python 3.12.8 environment at: /opt/conda
# Checked 1 package in 8ms
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Load data

# %% [markdown]
# A text file has been prepared as the source document for the downstream embedding task.
#
# Now, let's download and load it using LangChain's `TextLoader`.

# %%
# !wget "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/i5V3ACEyz6hnYpVq6MTSvg/state-of-the-union.txt"
# Out:
# --2026-06-05 17:52:34--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/i5V3ACEyz6hnYpVq6MTSvg/state-of-the-union.txt
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.63.118.104
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.63.118.104|:443... connected.
# 200 OKequest sent, awaiting response...
# Length: 39027 (38K) [text/plain]
# Saving to: ‘state-of-the-union.txt.1’
#
# state-of-the-union. 100%[===================>]  38.11K  --.-KB/s    in 0.001s
#
# 2026-06-05 17:52:35 (40.7 MB/s) - ‘state-of-the-union.txt.1’ saved [39027/39027]

# %%
from langchain_community.document_loaders import TextLoader

# %%
loader = TextLoader("state-of-the-union.txt")
data = loader.load()

# %% [markdown]
# Let's take a look at the document.

# %%
data[0].page_content[:1000]
# Out:
# 'Madam Speaker, Madam Vice President, our First Lady and Second Gentleman. Members of Congress and the Cabinet. Justices of the Supreme Court. My fellow Americans.  \n\nLast year COVID-19 kept us apart. This year we are finally together again. \n\nTonight, we meet as Democrats Republicans and Independents. But most importantly as Americans. \n\nWith a duty to one another to the American people to the Constitution. \n\nAnd with an unwavering resolve that freedom will always triumph over tyranny. \n\nSix days ago, Russia’s Vladimir Putin sought to shake the foundations of the free world thinking he could make it bend to his menacing ways. But he badly miscalculated. \n\nHe thought he could roll into Ukraine and the world would roll over. Instead he met a wall of strength he never imagined. \n\nHe met the Ukrainian people. \n\nFrom President Zelenskyy to every Ukrainian, their fearlessness, their courage, their determination, inspires the world. \n\nGroups of citizens blocking tanks with their bodies. Every'

# %% [markdown]
# ## Split data

# %% [markdown]
# Since the embedding model has a maximum input token limit, you cannot input the entire document at once. Instead, you need to split it into chunks.
#
# The following code shows how to use LangChain's `RecursiveCharacterTextSplitter` to split the document into chunks.
# - Use the default separator list, which is `["\n\n", "\n", " ", ""]`.
# - Chunk size is set to `100`. This should be set to less than the model's maximum input token.
# - Chunk overlap is set to `20`.
# - The length function is `len`.

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=100,
    chunk_overlap=20,
    length_function=len,
)

# %%
chunks = text_splitter.split_text(data[0].page_content)

# %% [markdown]
# Let's see how many chunks you get.

# %%
len(chunks)
# Out:
# 570

# %% [markdown]
# Let's also see what these chunks looks like.

# %%
chunks[:100]
# Out:
# ['Madam Speaker, Madam Vice President, our First Lady and Second Gentleman. Members of Congress and',
#  'of Congress and the Cabinet. Justices of the Supreme Court. My fellow Americans.',
#  'Last year COVID-19 kept us apart. This year we are finally together again.',
#  'Tonight, we meet as Democrats Republicans and Independents. But most importantly as Americans.',
#  'With a duty to one another to the American people to the Constitution.',
#  'And with an unwavering resolve that freedom will always triumph over tyranny.',
#  'Six days ago, Russia’s Vladimir Putin sought to shake the foundations of the free world thinking he',
#  'world thinking he could make it bend to his menacing ways. But he badly miscalculated.',
#  'He thought he could roll into Ukraine and the world would roll over. Instead he met a wall of',
#  'he met a wall of strength he never imagined.',
#  'He met the Ukrainian people.',
#  'From President Zelenskyy to every Ukrainian, their fearlessness, their courage, their',
#  'courage, their determination, inspires the world.',
#  'Groups of citizens blocking tanks with their bodies. Everyone from students to retirees teachers',
#  'retirees teachers turned soldiers defending their homeland.',
#  'In this struggle as President Zelenskyy said in his speech to the European Parliament “Light will',
#  '“Light will win over darkness.” The Ukrainian Ambassador to the United States is here tonight.',
#  'Let each of us here tonight in this Chamber send an unmistakable signal to Ukraine and to the',
#  'Ukraine and to the world.',
#  'Please rise if you are able and show that, Yes, we the United States of America stand with the',
#  'stand with the Ukrainian people.',
#  'Throughout our history we’ve learned this lesson when dictators do not pay a price for their',
#  'a price for their aggression they cause more chaos.',
#  'They keep moving.   \n\nAnd the costs and the threats to America and the world keep rising.',
#  'That’s why the NATO Alliance was created to secure peace and stability in Europe after World War 2.',
#  'after World War 2.',
#  'The United States is a member along with 29 other nations.',
#  'It matters. American diplomacy matters. American resolve matters.',
#  'Putin’s latest attack on Ukraine was premeditated and unprovoked.',
#  'He rejected repeated efforts at diplomacy.',
#  'He thought the West and NATO wouldn’t respond. And he thought he could divide us at home. Putin was',
#  'at home. Putin was wrong. We were ready.  Here is what we did.',
#  'We prepared extensively and carefully.',
#  'We spent months building a coalition of other freedom-loving nations from Europe and the Americas',
#  'and the Americas to Asia and Africa to confront Putin.',
#  'I spent countless hours unifying our European allies. We shared with the world in advance what we',
#  'in advance what we knew Putin was planning and precisely how he would try to falsely justify his',
#  'falsely justify his aggression.',
#  'We countered Russia’s lies with truth.',
#  'And now that he has acted the free world is holding him accountable.',
#  'Along with twenty-seven members of the European Union including France, Germany, Italy, as well as',
#  'Italy, as well as countries like the United Kingdom, Canada, Japan, Korea, Australia, New Zealand,',
#  'New Zealand, and many others, even Switzerland.',
#  'We are inflicting pain on Russia and supporting the people of Ukraine. Putin is now isolated from',
#  'now isolated from the world more than ever.',
#  'Together with our allies –we are right now enforcing powerful economic sanctions.',
#  'We are cutting off Russia’s largest banks from the international financial system.',
#  'Preventing Russia’s central bank from defending the Russian Ruble making Putin’s $630 Billion “war',
#  '$630 Billion “war fund” worthless.',
#  'We are choking off Russia’s access to technology that will sap its economic strength and weaken its',
#  'and weaken its military for years to come.',
#  'Tonight I say to the Russian oligarchs and corrupt leaders who have bilked billions of dollars off',
#  'of dollars off this violent regime no more.',
#  'The U.S. Department of Justice is assembling a dedicated task force to go after the crimes of',
#  'after the crimes of Russian oligarchs.',
#  'We are joining with our European allies to find and seize your yachts your luxury apartments your',
#  'apartments your private jets. We are coming for your ill-begotten gains.',
#  'And tonight I am announcing that we will join our allies in closing off American air space to all',
#  'air space to all Russian flights – further isolating Russia – and adding an additional squeeze –on',
#  'squeeze –on their economy. The Ruble has lost 30% of its value.',
#  'The Russian stock market has lost 40% of its value and trading remains suspended. Russia’s economy',
#  'Russia’s economy is reeling and Putin alone is to blame.',
#  'Together with our allies we are providing support to the Ukrainians in their fight for freedom.',
#  'fight for freedom. Military assistance. Economic assistance. Humanitarian assistance.',
#  'We are giving more than $1 Billion in direct assistance to Ukraine.',
#  'And we will continue to aid the Ukrainian people as they defend their country and to help ease',
#  'and to help ease their suffering.',
#  'Let me be clear, our forces are not engaged and will not engage in conflict with Russian forces in',
#  'Russian forces in Ukraine.',
#  'Our forces are not going to Europe to fight in Ukraine, but to defend our NATO Allies – in the',
#  'Allies – in the event that Putin decides to keep moving west.',
#  'For that purpose we’ve mobilized American ground forces, air squadrons, and ship deployments to',
#  'ship deployments to protect NATO countries including Poland, Romania, Latvia, Lithuania, and',
#  'Lithuania, and Estonia.',
#  'As I have made crystal clear the United States and our Allies will defend every inch of territory',
#  'inch of territory of NATO countries with the full force of our collective power.',
#  'And we remain clear-eyed. The Ukrainians are fighting back with pure courage. But the next few days',
#  'the next few days weeks, months, will be hard on them.',
#  'Putin has unleashed violence and chaos.  But while he may make gains on the battlefield – he will',
#  '– he will pay a continuing high price over the long run.',
#  'And a proud Ukrainian people, who have known 30 years  of independence, have repeatedly shown that',
#  'shown that they will not tolerate anyone who tries to take their country backwards.',
#  'To all Americans, I will be honest with you, as I’ve always promised. A Russian dictator, invading',
#  'dictator, invading a foreign country, has costs around the world.',
#  'And I’m taking robust action to make sure the pain of our sanctions  is targeted at Russia’s',
#  'at Russia’s economy. And I will use every tool at our disposal to protect American businesses and',
#  'businesses and consumers.',
#  'Tonight, I can announce that the United States has worked with 30 other countries to release 60',
#  'to release 60 Million barrels of oil from reserves around the world.',
#  'America will lead that effort, releasing 30 Million barrels from our own Strategic Petroleum',
#  'Strategic Petroleum Reserve. And we stand ready to do more if necessary, unified with our allies.',
#  'These steps will help blunt gas prices here at home. And I know the news about what’s happening can',
#  'happening can seem alarming.',
#  'But I want you to know that we are going to be okay.',
#  'When the history of this era is written Putin’s war on Ukraine will have left Russia weaker and the',
#  'weaker and the rest of the world stronger.',
#  'While it shouldn’t have taken something so terrible for people around the world to see what’s at',
#  'to see what’s at stake now everyone sees it clearly.',
#  'We see the unity among leaders of nations and a more unified Europe a more unified West. And we see',
#  'West. And we see unity among the people who are gathering in cities in large crowds around the']

# %% [markdown]
# ## Watsonx embedding model

# %% [markdown]
# ### Model description

# %% [markdown]
# In this section, you will use IBM `slate-125m-english-rtrvr-v2` model as an example embedding model.
#
# The `slate.125m.english.rtrvr` model is a [standard sentence](https://www.sbert.net/) transformers model based on bi-encoders. The model produces an embedding for a given input, e.g., query, passage, document, etc. At a high level, the model is trained to maximize the cosine similarity between two input pieces of text, e.g., text A (query text) and text B (passage text), which results in the sentence embeddings q and p.These sentence embeddings can be compared using cosine similarity, which measures the distance between sentences by calculating the distance between their embeddings.

# %% [markdown]
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/NDCHhZfcC96jggb2hMdJhg/fm-slate-125m-english-rtrvr-cosine.jpg" width="50%">

# %% [markdown]
# The embedding model, `slate-125m-english-rtrvr-v2` formerly known as WatBERT, has the same architecture as a RoBERTa base transformer model and has ~125 million parameters and an embedding dimension of `768`.

# %% [markdown]
# |Model name|API model_id|Maximum input tokens|Number of dimensions|More information|
# |-|-|-|-|-|
# |slate-125m-english-rtrvr-v2|ibm/slate-125m-english-rtrvr-v2|512|768|[model card](https://dataplatform.cloud.ibm.com/docs/content/wsj/analyze-data/fm-slate-125m-english-rtrvr-v2-model-card.html?utm_source=skills_network&utm_content=in_lab_content_link&utm_id=Lab-Embed+documents+with+watsonx%E2%80%99s+embedding-v1_1761934835&context=wx&audience=wdp)|

# %% [markdown]
# ### Build model

# %% [markdown]
# The following code shows how to build the `slate-125m-english-rtrvr-v2` model from IBM watsonx.ai API.

# %% [markdown]
# First, import the necessary dependencies.
# - `WatsonxEmbeddings` is a class/dependence that can be used to form an embedding model object.
# - `EmbedTextParamsMetaNames` is a dependence that controls the embedding parameters.

# %%
from ibm_watsonx_ai.metanames import EmbedTextParamsMetaNames
from langchain_ibm import WatsonxEmbeddings

# %%
embed_params = {
    EmbedTextParamsMetaNames.TRUNCATE_INPUT_TOKENS: 3,
    EmbedTextParamsMetaNames.RETURN_OPTIONS: {"input_text": True},
}

watsonx_embedding = WatsonxEmbeddings(
    model_id="ibm/slate-125m-english-rtrvr-v2",
    url="https://us-south.ml.cloud.ibm.com",
    project_id="skills-network",
    params=embed_params,
)

# %% [markdown]
# ### Query embeddings

# %% [markdown]
# Now, create an embedding based on a single sentence, which can be treated as a query.

# %% [markdown]
# Use the `embed_query` method.

# %%
query = "How are you?"

query_result = watsonx_embedding.embed_query(query)

# %% [markdown]
# Let's see the length/dimension of this embedding.

# %%
len(query_result)
# Out:
# 768

# %% [markdown]
# It has a dimension of `768`, which aligns with the model description.

# %% [markdown]
# Next, take a look at the first five results from the embeddings.

# %%
query_result[:5]
# Out:
# [-0.03113516978919506,
#  -0.003913179971277714,
#  -0.0031165573745965958,
#  -0.03244868293404579,
#  -0.04062166437506676]

# %% [markdown]
# ### Document embeddings

# %% [markdown]
# After creating the query embeddings, you will be guided on how to create embeddings from documents, which are a list a text chunks.

# %% [markdown]
# Use `embed_documents`. The parameter `chunks` should be a list of text. Here, chunks is a list of documents you get from before after splitting the whole document.

# %%
doc_result = watsonx_embedding.embed_documents(chunks)

# %% [markdown]
# As each piece of text is embedded into a vector, so the length of the `doc_result` should be the same as the length of chunks.

# %%
len(doc_result)
# Out:
# 570

# %% [markdown]
# Now, take a look at the first five results from the embeddings of the first piece of text.

# %%
doc_result[0][:5]
# Out:
# [-0.03984632343053818,
#  0.021853603422641754,
#  -0.015084679238498211,
#  0.01978703960776329,
#  -0.05613134056329727]

# %% [markdown]
# Check the embedding dimension to see if it is also 768.

# %%
len(doc_result[0])
# Out:
# 768

# %% [markdown]
# ## Hugging Face embedding model

# %% [markdown]
# ### Model description

# %% [markdown]
# In this section, you will use the `all-mpnet-base-v2` from HuggingFace as an example embedding model.
#
# It is a sentence-transformers model. It maps sentences and paragraphs to a 768-dimensional dense vector space and can be used for tasks like clustering or semantic search. It used the pre-trained `Microsoft/money-base` model and fine-tuned it on a 1B sentence pairs dataset. For more information, please refer to [here](https://huggingface.co/sentence-transformers/all-mpnet-base-v2).

# %% [markdown]
# ### Build model

# %% [markdown]
# To build the model, you need to import the `HuggingFaceEmbeddings` dependence first.

# %%
#!pip install -U langchain-huggingface
#from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.embeddings import HuggingFaceEmbeddings

# %% [markdown]
# Then, you specify the model name.

# %%
model_name = "sentence-transformers/all-mpnet-base-v2"

# %% [markdown]
# Here we create a embedding model object.

# %%
huggingface_embedding = HuggingFaceEmbeddings(model_name=model_name)
# Out:
# /tmp/ipykernel_557/103517808.py:1: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 0.3.0. An updated version of the class exists in the langchain-huggingface package and should be used instead. To use it run `pip install -U langchain-huggingface` and import as `from langchain_huggingface import HuggingFaceEmbeddings`.
#   huggingface_embedding = HuggingFaceEmbeddings(model_name=model_name)
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %% [markdown]
# ### Query embeddings

# %% [markdown]
# Let's create the embeddings from the same sentence, but using the Hugging Face embedding model.

# %%
query = "How are you?"

# %%
query_result = huggingface_embedding.embed_query(query)

# %%
query_result[:5]
# Out:
# [0.027106190100312233,
#  0.011331873945891857,
#  -0.0019524097442626953,
#  -0.03695132955908775,
#  0.017764898017048836]

# %% [markdown]
# Do you see the differences between embeddings that are created by the watsonx embedding model and the Hugging Face embedding model?

# %% [markdown]
# ### Document embeddings

# %% [markdown]
# Next, you can do the same for creating embeddings from documents.

# %%
doc_result = huggingface_embedding.embed_documents(chunks)
doc_result[0][:5]
# Out:
# [0.04028428718447685,
#  0.030196433886885643,
#  -0.006393824703991413,
#  0.06266556680202484,
#  -0.007770853582769632]

# %%
len(doc_result[0])
# Out:
# 768

# %% [markdown]
# # Exercises

# %% [markdown]
# ### Exercise 1 - Using another watsonx embedding model
# Watsonx.ai also supports other embedding models, for which you can find more information [here](https://www.ibm.com/products/watsonx-ai/foundation-models?utm_source=skills_network&utm_content=in_lab_content_link&utm_id=Lab-Embed+documents+with+watsonx%E2%80%99s+embedding-v1_1761934835#embedding). Can you try to use another embedding model to create embeddings for the document?

# %%
from langchain.document_loaders import TextLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_ibm import WatsonxEmbeddings
from ibm_watsonx_ai.metanames import EmbedTextParamsMetaNames

#Load Text
text_loader = TextLoader(file_path='state-of-the-union.txt')
text = text_loader.load()

#Split Text
text_splitter = RecursiveCharacterTextSplitter(chunk_size=200,chunk_overlap=20)
texts = text_splitter.split_text(text[0].page_content)

#Create Embeddings
embed_params = {
    EmbedTextParamsMetaNames.TRUNCATE_INPUT_TOKENS: 3,
    EmbedTextParamsMetaNames.RETURN_OPTIONS: {"input_text": True},
}

watsonx_embedding = WatsonxEmbeddings(
    model_id="ibm/slate-30m-english-rtrvr-v2",
    url="https://us-south.ml.cloud.ibm.com",
    project_id="skills-network",
    params=embed_params,
)

embeddings = watsonx_embedding.embed_documents(texts=texts)
print(embeddings[0][:10])
# Out:
# [-0.0766424685716629, 0.05399184674024582, 0.014972611330449581, -0.0036153497640043497, -0.0348803848028183, -0.06224988400936127, -0.04856513440608978, 0.03079068847000599, 0.03283553570508957, 0.037672389298677444]

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
#
# from ibm_watsonx_ai.metanames import EmbedTextParamsMetaNames
# from langchain_ibm import WatsonxEmbeddings
#
# embed_params = {
#     EmbedTextParamsMetaNames.TRUNCATE_INPUT_TOKENS: 3,
#     EmbedTextParamsMetaNames.RETURN_OPTIONS: {"input_text": True},
# }
#
# watsonx_embedding = WatsonxEmbeddings(
#     model_id="ibm/slate-30m-english-rtrvr-v2",
#     url="https://us-south.ml.cloud.ibm.com",
#     project_id="skills-network",
#     params=embed_params,
# )
#
# doc_result = watsonx_embedding.embed_documents(chunks)
#
# doc_result[0][:5]
#
# ```
#
# </details>
